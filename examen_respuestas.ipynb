# %% [markdown]
# En el repositorio:&nbsp;
#
# https://github.com/chernandezmar/PID_apuntes/
#
# encontraran un nuevo branch llamado ev1, dentro encontraran 2 nuevos datasets:
#
# ./dataset/Apache.log
# ./dataset/Linux.log
#
#
#
#
# Contestar la sigueinte pregunta:
# que hace el siguiente comando:
#
# cut -d' ' -f 1-5
#
#
#
#
#
# Realizaran un notebook en Jupyter donde usando markdown explicaran brevemente de que trata cada uno de estos nuevos datasets.
#
#
# ademas de contestar las siguientes preguntas, mostrando en el notebook el comando que utilizaste
#
#
# Linux.log
#
# Numero de lineas
# Numero de palabras
# Numero de caracteres
# Numero de Eventos por mes
# De los eventos con el string "authentication failure" obtener el listado de usuarios, y cuantos eventos tienen
# Lista de ips que establecieron conexion via FTP y cuantas conexiones realizaron
#
# Apache.log
#
# Numero Lineas
# Numero de Eventos por mes
# Numero de eventos por categoria: notice, error, warn
# De los eventos tipo error, obtener el listado de clients
# De los eventos tipo error, obtener el listado de archivos que no existen
#
#
#
#
# Como les comente deberan de mostrar en el notebook los comandos que utilizaron, ademas de subirlo a un repositorio propio
#
# Entrega:
#
# url del repo donde subieron el notebook

# %%
# !head datasets/Linux.log
# Out:
# Jun  9 06:06:20 combo syslogd 1.4.1: restart.
# Jun  9 06:06:20 combo syslog: syslogd startup succeeded
# Jun  9 06:06:20 combo syslog: klogd startup succeeded
# Jun  9 06:06:20 combo kernel: klogd 1.4.1, log source = /proc/kmsg started.
# Jun  9 06:06:20 combo kernel: Linux version 2.6.5-1.358 (bhcompile@bugs.build.redhat.com) (gcc version 3.3.3 20040412 (Red Hat Linux 3.3.3-7)) #1 Sat May 8 09:04:50 EDT 2004
# Jun  9 06:06:20 combo kernel: BIOS-provided physical RAM map:
# Jun  9 06:06:20 combo kernel:  BIOS-e820: 0000000000000000 - 00000000000a0000 (usable)
# Jun  9 06:06:20 combo kernel:  BIOS-e820: 00000000000f0000 - 0000000000100000 (reserved)
# Jun  9 06:06:20 combo kernel:  BIOS-e820: 0000000000100000 - 0000000007eae000 (usable)
# Jun  9 06:06:20 combo kernel:  BIOS-e820: 0000000007eae000 - 0000000008000000 (reserved)

# %%
# !head datasets/Linux.log | cut -d' ' -f 4-5
# Out:
# 06:06:20 combo
# 06:06:20 combo
# 06:06:20 combo
# 06:06:20 combo
# 06:06:20 combo
# 06:06:20 combo
# 06:06:20 combo
# 06:06:20 combo
# 06:06:20 combo
# 06:06:20 combo

# %% [markdown]
# # Linux.log

# %% [markdown]
# - Numero de lineas
# - Numero de palabras
# - Numero de caracteres

# %%
filename = "datasets/Linux.log"

# %%
# !cat $filename | wc
# Out:
#    25567  308039 2349446

# %% [markdown]
# Numero de Eventos por mes

# %%
# !cat $filename | cut -d' ' -f1 | sort | uniq -c
# Out:
# 1208 Aug
# 4750 Dec
# 1222 Feb
# 2439 Jan
# 1659 Jul
# 1605 Jun
# 9315 Nov
# 1540 Oct
# 1829 Sep

# %% [markdown]
# De los eventos con el string "authentication failure" obtener el listado de usuarios, y cuantos eventos tienen

# %%
# !cat $filename | grep 'authentication failure' | cut -d'=' -f8 | sort | uniq -c | sort -n
# Out:
#    1 info
#    5 postfix
#   10 adm
#   16 webmaster
#   21 ftp
#   23 guest
#   26 amanda
#   29 fax
#   96 nobody
#  412 test
# 1043
# 2258 root

# %%
# !cat $filename | grep 'authentication failure' | grep -v ' user=' | wc -l
# Out:
#     1043

# %% [markdown]
# cuantos eventos tienen Lista de ips que establecieron conexion via FTP y cuantas conexiones realizaron

# %%
# !cat $filename | grep ftp | cut -d' ' -f8 | sort | uniq -c | sort -n
# Out:
#    1 218.38.58.3
#    1 64.203.6.90
#    2
#    2 218.241.72.44
#    2 68.206.240.214
#    2 81.181.213.88
#    3 89.52.86.249
#    3 LOGIN
#    4 89.52.108.44
#    5 89.52.108.101
#    6 101.118.47.108
#    6 84.184.55.118
#    6 Operation
#    7 210.223.97.117
#    7 86.193.175.220
#    8 24.54.76.216
#    8 FTP
#    9 210.114.223.52
#    9 84.102.20.91
#   12 210.21.220.88
#   12 213.232.120.139
#   12 213.54.172.95
#   12 timed
#   13 211.167.68.59
#   13 218.69.108.57
#   13 69.177.104.55
#   15 86.193.48.194
#   16 217.46.152.45
#   16 218.28.1.61
#   16 84.184.10.83
#   17 (ftpd):
#   17 200.61.161.145
#   18 210.118.170.95
#   18 66.15.25.56
#   19 217.187.83.50
#   19 219.145.93.74
#   19 219.96.194.251
#   19 61.199.220.226
#   19 84.184.71.145
#   19 85.219.160.32
#   20 218.242.202.99
#   20 85.182.21.189
#   21 64.27.5.9
#   21 84.158.123.165
#   21 84.160.176.141
#   21 logname=
#   22 202.147.190.179
#   22 61.33.224.81
#   22 82.252.162.81
#   23 148.223.155.2
# ...

# %%
# !cat $filename | grep ftp | grep 'connection from' | grep -v 'user=ftp' | grep -v kernel | sed 's/  / /g' | cut -d' ' -f8 | sort | uniq -c | sort -n
# Out:
#    1 218.38.58.3
#    1 64.203.6.90
#    2 213.169.189.194
#    2 218.241.72.44
#    2 68.206.240.214
#    2 81.181.213.88
#    2 81.53.90.34
#    3 89.52.86.249
#    4 89.52.108.44
#    5 89.52.108.101
#    6 101.118.47.108
#    6 217.189.178.104
#    6 84.184.55.118
#    7 210.223.97.117
#    7 86.193.175.220
#    8 24.54.76.216
#    8 81.240.142.171
#    9 210.114.223.52
#    9 216.123.77.195
#    9 84.102.20.91
#   12 210.21.220.88
#   12 213.232.120.139
#   12 213.54.172.95
#   13 218.69.108.57
#   13 69.177.104.55
#   15 86.193.48.194
#   16 210.202.115.220
#   16 217.46.152.45
#   16 218.28.1.61
#   16 84.184.10.83
#   17 200.61.161.145
#   18 210.118.170.95
#   18 212.192.157.99
#   18 66.15.25.56
#   18 69.66.196.20
#   19 217.187.83.50
#   19 219.145.93.74
#   19 219.96.194.251
#   19 221.4.102.93
#   19 222.90.77.158
#   19 61.199.220.226
#   19 84.184.71.145
#   19 85.219.160.32
#   20 218.242.202.99
#   20 85.182.21.189
#   21 64.27.5.9
#   21 64.34.92.187
# ...

# %% [markdown]
# # Apache.log

# %% [markdown]
# - Numero Lineas
# - Numero de Eventos por mes
# - Numero de eventos por categoria: notice, error, warn
# - De los eventos tipo error, obtener el listado de clients
# - De los eventos tipo error, obtener el listado de archivos que no existen

# %%
filename2 = "datasets/Apache.log"

# %%
# !wc -l $filename
# Out:
#    25567 datasets/Linux.log

# %%
# !cat $filename2 | grep -v 'script not found' |cut -d' ' -f2 | sort | uniq -c | sort -n
# Out:
# 1122 Oct
# 1358 Aug
# 1753 Sep
# 2491 Jun
# 3152 Jul
# 6050 Dec
# 8225 Feb
# 9299 Jan
# 15253 Nov

# %% [markdown]
# porque ese not?

# %%
# !cat $filename2 | grep -v 'script not found' | cut -d'[' -f3 | cut -d ']' -f1 | sort | uniq -c | sort -n
# Out:
#  168 warn
# 13755 notice
# 34780 error

# %%
cat $filename2 | grep 'error' | grep 'client' | cut -d' ' -f8 | sed 's/]//g' | sort | uniq -c | sort -n
# Out:
#    1 12.0.102.64
#    1 12.124.47.242
#    1 12.127.69.10
#    1 12.134.92.145
#    1 12.14.128.253
#    1 12.145.34.103
#    1 12.147.133.194
#    1 12.148.18.99
#    1 12.150.176.207
#    1 12.159.237.243
#    1 12.164.192.174
#    1 12.164.75.135
#    1 12.166.81.198
#    1 12.172.137.4
#    1 12.175.240.81
#    1 12.202.100.234
#    1 12.202.209.209
#    1 12.202.95.162
#    1 12.205.52.60
#    1 12.206.61.56
#    1 12.207.95.42
#    1 12.208.0.159
#    1 12.208.194.107
#    1 12.208.195.70
#    1 12.21.245.2
#    1 12.210.40.134
#    1 12.214.70.84
#    1 12.216.13.189
#    1 12.216.230.125
#    1 12.219.233.24
#    1 12.219.241.72
#    1 12.22.215.71
#    1 12.222.57.26
#    1 12.223.199.82
#    1 12.223.34.175
#    1 12.223.73.171
#    1 12.226.50.50
#    1 12.226.83.250
#    1 12.29.238.34
#    1 12.3.170.61
#    1 12.33.166.9
#    1 12.34.17.67
#    1 12.34.17.71
#    1 12.40.63.20
#    1 12.41.135.236
#    1 12.43.237.114
#    1 12.46.1.94
#    1 12.47.250.82
# ...

# %%
cat $filename2 | grep 'error' | grep 'File does not exist' | cut -d':' -f4 | sort | uniq -c | sort -n
# Out:
#    1  /var/www/html/install
#    2  /var/www/html/twiki
#    6  /var/www/html/cgi-local
#    6  /var/www/html/chat
#    6  /var/www/html/msgboard
#    6  /var/www/html/phpbb
#    6  /var/www/html/talk
#    6  /var/www/html/~mana_
#    9  /var/www/html/catalog
#    9  /var/www/html/onlineshop
#    9  /var/www/html/osCommerce
#    9  /var/www/html/osc
#    9  /var/www/html/oscommerce
#    9  /var/www/html/shop
#    9  /var/www/html/store
#   10  /var/www/html/~ipcom
#   11  /var/www/html/qnews
#   12  /var/www/html/Forums
#   12  /var/www/html/b2exo
#   12  /var/www/html/forum/include
#   12  /var/www/html/local_graph_id
#   12  /var/www/html/trunk
#   13  /var/www/html/Mambo
#   13  /var/www/html/include
#   13  /var/www/html/wing-calendar
#   14  /var/www/html/NULL.printer
#   17  /var/www/html/favicon.ico
#   22  /var/www/html/Calendar
#   22  /var/www/html/awstats/perl
#   22  /var/www/html/cal
#   22  /var/www/html/calendar
#   22  /var/www/html/ip1.cgi
#   23  /var/www/html/...
# ...
